# %%
import os
import glob 

import numpy as np 
import matplotlib.pyplot as plt

# %%
def timestamp(filename):
    """
    Returns the numpy datetime 64 [ns] for the current date.
    This is a bit hardcoded at the moment ....
    """
    splits = filename.split('-')
    ts = splits[5]
    year = ts[:4]
    month = ts[4:6]
    day = ts[6:8]
    hr = ts[8:10]
    minuts = ts[10:12]
    sek = ts[12:14]
    return np.datetime64( year+"-"+month+"-"+day+"T"+hr )# +":"+minuts+":"+sek

# %%
path = '/uio/lagringshotell/geofag/projects/miphclac/hannasv/'

# %%
def get_folder(filname):
    "Returns the folder of a filename."
    splits = filename.split('-')
    ts = splits[5]
    year = ts[:4]
    month = ts[4:6]
    return '{}{}'.format(year, month)

# %%
years = np.arange(2004, 2013)
months = np.arange(1,13)

# %%
test_folder = '2005_01'
location = os.path.join( path, test_folder )
keys = test_folder.split('_')
search_key = '*{}{}*.grb'.format(keys[0], keys[1])

# %%
location
# Out:
# '/uio/lagringshotell/geofag/projects/miphclac/hannasv/2005_01'

# %%
import pandas as pd

# %%
len(files_in_folder), days
# Out:
# (652, 744)

# %%
for y in years:
    for m in months:
        m = "%2.2d" %m
        folder = '{}_{}'.format(y, m)
        location = os.path.join( path, folder )
        keys = folder.split('_')
        
        search_key = '*{}{}*.grb'.format(keys[0], keys[1])
        days = pd.Period('{}-{}'.format(keys[0], keys[1])).days_in_month*24
        a = os.path.join(location, search_key)
        #print(a)
        files_in_folder = glob.glob(a)
        print("Folder {} is hours {}, files {}".format(folder, days, len(files_in_folder)))
# Out:
# Folder 2004_01 is hours 744, files 0
# Folder 2004_02 is hours 696, files 0
# Folder 2004_03 is hours 744, files 0
# Folder 2004_04 is hours 720, files 690
# Folder 2004_05 is hours 744, files 744
# Folder 2004_06 is hours 720, files 718
# Folder 2004_07 is hours 744, files 743
# Folder 2004_08 is hours 744, files 742
# Folder 2004_09 is hours 720, files 720
# Folder 2004_10 is hours 744, files 668
# Folder 2004_11 is hours 720, files 720
# Folder 2004_12 is hours 744, files 856
# Folder 2005_01 is hours 744, files 652
# Folder 2005_02 is hours 672, files 671
# Folder 2005_03 is hours 744, files 740
# Folder 2005_04 is hours 720, files 710
# Folder 2005_05 is hours 744, files 740
# Folder 2005_06 is hours 720, files 716
# Folder 2005_07 is hours 744, files 743
# Folder 2005_08 is hours 744, files 743
# Folder 2005_09 is hours 720, files 719
# Folder 2005_10 is hours 744, files 744
# Folder 2005_11 is hours 720, files 719
# Folder 2005_12 is hours 744, files 850
# ...

# %%
ts_2010 = [timestamp(fil) for fil in files_in_folder]
_s = np.sort(ts_2010)
#dup = test_sequence(_s)
plt.plot(_s)
plt.show()

# %%
_s.astype(dataframe, )
# Out:
# array(['2005-01-01T00', '2005-01-01T01', '2005-01-01T02', '2005-01-01T03',
#        '2005-01-01T04', '2005-01-01T05', '2005-01-01T06', '2005-01-01T07',
#        '2005-01-01T08', '2005-01-01T09', '2005-01-01T10', '2005-01-01T11',
#        '2005-01-01T12', '2005-01-01T13', '2005-01-01T14', '2005-01-01T15',
#        '2005-01-01T16', '2005-01-01T17', '2005-01-01T18', '2005-01-01T19',
#        '2005-01-01T20', '2005-01-01T21', '2005-01-01T22', '2005-01-01T23',
#        '2005-01-02T00', '2005-01-02T01', '2005-01-02T02', '2005-01-02T03',
#        '2005-01-02T04', '2005-01-02T05', '2005-01-02T06', '2005-01-02T07',
#        '2005-01-02T08', '2005-01-02T09', '2005-01-02T10', '2005-01-02T11',
#        '2005-01-02T12', '2005-01-02T13', '2005-01-02T14', '2005-01-02T15',
#        '2005-01-02T16', '2005-01-02T17', '2005-01-02T18', '2005-01-02T19',
#        '2005-01-02T20', '2005-01-02T21', '2005-01-02T22', '2005-01-02T23',
# ...

# %%
dup = test_sequence(_s)
# Out:
# prev_ts 2005-01-01T00 and ts 2005-01-01T01 is note sequential. Missing data!!
# prev_ts 2005-01-01T01 and ts 2005-01-01T02 is note sequential. Missing data!!
# prev_ts 2005-01-01T02 and ts 2005-01-01T03 is note sequential. Missing data!!
# prev_ts 2005-01-01T03 and ts 2005-01-01T04 is note sequential. Missing data!!
# prev_ts 2005-01-01T04 and ts 2005-01-01T05 is note sequential. Missing data!!
# prev_ts 2005-01-01T05 and ts 2005-01-01T06 is note sequential. Missing data!!
# prev_ts 2005-01-01T06 and ts 2005-01-01T07 is note sequential. Missing data!!
# prev_ts 2005-01-01T07 and ts 2005-01-01T08 is note sequential. Missing data!!
# prev_ts 2005-01-01T08 and ts 2005-01-01T09 is note sequential. Missing data!!
# prev_ts 2005-01-01T09 and ts 2005-01-01T10 is note sequential. Missing data!!
# prev_ts 2005-01-01T10 and ts 2005-01-01T11 is note sequential. Missing data!!
# prev_ts 2005-01-01T11 and ts 2005-01-01T12 is note sequential. Missing data!!
# ...

# %%
def test_sequence(times):
    prev_ts = 0
    dT = np.timedelta64(21600000000000,'ns')
    duplicate_elements = []

    for i, ts in enumerate(times):
        if prev_ts == 0:
            prev_ts = ts
        else:
            if ts - prev_ts != dT:
                if prev_ts == ts:
                    duplicate_elements.append( (ts, len(times)-i ) )
                else:
                    print("prev_ts {} and ts {} is note sequential. Missing data!!".format(prev_ts, ts))
            prev_ts = ts
            
    return duplicate_elements

# %% [markdown]
# # Directory

# %% [markdown]
# 1340506  2010_more     2011                   2012_new  2014  2016  24thSep2010
# 2008     2010_tom_sep  2012_dobbelsjekk_alle  2013      2015  2017  more_2017

# %% [markdown]
# # 2010 - tom septempber OK

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2010_tom_sep/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()
# Out:
# /home/hanna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   import sys

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2010_more/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()
# Out:
# prev_ts 2010-10-13T18:00:00.000000000 and ts 2010-10-13T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2010-10-12T18:00:00.000000000 and ts 2010-10-12T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2010-09-24T18:00:00.000000000 and ts 2010-09-24T06:00:00.000000000 is note sequential. Missing data!!
# /home/hanna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   import sys

# %% [markdown]
# # 2011

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2011/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()
# Out:
# prev_ts 2011-10-14T18:00:00.000000000 and ts 2011-10-14T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2011-10-13T18:00:00.000000000 and ts 2011-10-13T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2011-10-12T18:00:00.000000000 and ts 2011-10-12T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2011-03-17T12:00:00.000000000 and ts 2011-03-17T00:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2011-03-01T18:00:00.000000000 and ts 2011-03-01T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2011-02-21T18:00:00.000000000 and ts 2011-02-21T06:00:00.000000000 is note sequential. Missing data!!
# /home/hanna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   import sys

# %%
dup
# Out:
# [(numpy.datetime64('2013-02-19T06:00:00.000000000'), 394),
#  (numpy.datetime64('2013-02-19T00:00:00.000000000'), 392),
#  (numpy.datetime64('2013-02-18T18:00:00.000000000'), 390),
#  (numpy.datetime64('2013-02-18T12:00:00.000000000'), 388),
#  (numpy.datetime64('2013-02-18T06:00:00.000000000'), 386),
#  (numpy.datetime64('2013-02-18T00:00:00.000000000'), 384),
#  (numpy.datetime64('2013-02-17T18:00:00.000000000'), 382),
#  (numpy.datetime64('2013-02-17T12:00:00.000000000'), 380),
#  (numpy.datetime64('2013-02-17T06:00:00.000000000'), 378),
#  (numpy.datetime64('2013-02-17T00:00:00.000000000'), 376),
#  (numpy.datetime64('2013-02-16T18:00:00.000000000'), 374),
#  (numpy.datetime64('2013-02-16T12:00:00.000000000'), 372),
#  (numpy.datetime64('2013-02-16T06:00:00.000000000'), 370),
#  (numpy.datetime64('2013-02-16T00:00:00.000000000'), 368),
#  (numpy.datetime64('2013-02-15T18:00:00.000000000'), 366),
#  (numpy.datetime64('2013-02-15T12:00:00.000000000'), 364),
# ...

# %% [markdown]
# # 2013

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2013/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()
# Out:
# prev_ts 2013-10-14T18:00:00.000000000 and ts 2013-10-14T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2013-10-13T18:00:00.000000000 and ts 2013-10-13T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2013-10-12T18:00:00.000000000 and ts 2013-10-12T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2013-08-18T18:00:00.000000000 and ts 2013-08-18T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2013-07-05T06:00:00.000000000 and ts 2013-07-04T18:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2013-02-24T12:00:00.000000000 and ts 2013-02-24T00:00:00.000000000 is note sequential. Missing data!!
# /home/hanna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   import sys

# %%
len(dup)
# Out:
# 197

# %% [markdown]
# # 2014

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2014/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()
# Out:
# prev_ts 2014-03-09T12:00:00.000000000 and ts 2014-03-09T00:00:00.000000000 is note sequential. Missing data!!
# /home/hanna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   import sys

# %%
dup
# Out:
# []

# %% [markdown]
# # 2015

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2015/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()
# Out:
# prev_ts 2015-11-15T12:00:00.000000000 and ts 2015-11-15T00:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2015-10-12T18:00:00.000000000 and ts 2015-10-12T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2015-10-11T18:00:00.000000000 and ts 2015-10-11T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2015-07-01T06:00:00.000000000 and ts 2015-06-30T18:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2015-04-28T18:00:00.000000000 and ts 2015-04-28T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2015-03-12T18:00:00.000000000 and ts 2015-03-12T06:00:00.000000000 is note sequential. Missing data!!
# prev_ts 2015-02-08T06:00:00.000000000 and ts 2015-02-07T18:00:00.000000000 is note sequential. Missing data!!
# /home/hanna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   import sys

# %%
dup
# Out:
# [(numpy.datetime64('2015-05-20T12:00:00.000000000'), 630),
#  (numpy.datetime64('2015-05-20T12:00:00.000000000'), 629),
#  (numpy.datetime64('2015-05-20T06:00:00.000000000'), 627),
#  (numpy.datetime64('2015-05-20T00:00:00.000000000'), 625),
#  (numpy.datetime64('2015-05-19T18:00:00.000000000'), 623),
#  (numpy.datetime64('2015-05-19T12:00:00.000000000'), 621),
#  (numpy.datetime64('2015-05-19T06:00:00.000000000'), 619),
#  (numpy.datetime64('2015-05-19T00:00:00.000000000'), 617),
#  (numpy.datetime64('2015-05-18T18:00:00.000000000'), 615),
#  (numpy.datetime64('2015-05-18T12:00:00.000000000'), 613),
#  (numpy.datetime64('2015-05-18T06:00:00.000000000'), 611),
#  (numpy.datetime64('2015-05-18T00:00:00.000000000'), 609),
#  (numpy.datetime64('2015-05-17T18:00:00.000000000'), 607),
#  (numpy.datetime64('2015-05-17T12:00:00.000000000'), 605),
#  (numpy.datetime64('2015-05-17T06:00:00.000000000'), 603),
#  (numpy.datetime64('2015-05-17T00:00:00.000000000'), 601),
# ...

# %% [markdown]
# ###  2016

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2016/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()

# %% [markdown]
# # 2017

# %%
files_2010 = glob.glob("./MSG_0_degree_X/archive.eumetsat.int/"+
          "umarf/onlinedownload/hannasv/2017/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()
# Out:
# prev_ts 2017-09-22T18:00:00.000000000 and ts 2017-09-22T06:00:00.000000000 is note sequential. Missing data!!
# /home/hanna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   import sys

# %% [markdown]
# # 2018

# %%
files_2010 = glob.glob("./satelite_data_raw/2018/*grb")
ts_2010 = [timestamp(fil) for fil in files_2010]
_s = np.sort(ts_2010)
dup = test_sequence(_s)
plt.plot(_s)
plt.show()

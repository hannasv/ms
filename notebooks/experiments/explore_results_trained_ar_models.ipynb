# %% [markdown]
# # Study trained AR models

# %%
import os
import glob

import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

# %%
results_dir = '/home/hanna/lagrings/results/ar/'

# %%
glob.glob(results_dir + '*.nc')
# Out:
# ['/home/hanna/lagrings/results/ar/AR_2020-04-05T07:39:06.nc',
#  '/home/hanna/lagrings/results/ar/AR_2020-04-05T07:22:51.nc',
#  '/home/hanna/lagrings/results/ar/AR_2020-04-07T06:33:31.nc',
#  '/home/hanna/lagrings/results/ar/AR_2020-04-04T08:22:54.nc',
#  '/home/hanna/lagrings/results/ar/AR_2020-04-04T13:21:55.nc',
#  '/home/hanna/lagrings/results/ar/AR_2020-04-04T15:37:03.nc',
#  '/home/hanna/lagrings/results/ar/AR_2020-04-04T16:45:11.nc',
#  '/home/hanna/lagrings/results/ar/AR_traditional2020-05-09T11:49:09.nc',
#  '/home/hanna/lagrings/results/ar/AR_traditional2020-05-09T18:19:23.nc',
#  '/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T10:00:59.nc',
#  '/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T11:13:41.nc',
#  '/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T17:28:25.nc',
#  '/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T19:25:28.nc']

# %%
from sclouds.ml.regression.AR_model_loader import AR_model_loader
# Out:
# Warning.. Using pgf backend, no GUI available. use plt.savefig() for inpection

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-329ad35cb868> in <module>
#       2 import numpy.ma as ma
#       3
# ----> 4 a=ma.masked_invalid(A)
#       5 b=ma.masked_invalid(B)
#       6
#
# NameError: name 'A' is not defined

# %%
m1
# Out:
# <xarray.Dataset>
# Dimensions:            (latitude: 81, longitude: 161)
# Coordinates:
#   * longitude          (longitude) float64 -15.0 -14.75 -14.5 ... 24.75 25.0
#   * latitude           (latitude) float64 30.0 30.25 30.5 ... 49.5 49.75 50.0
# Data variables:
#     transform          bool True
#     sigmoid            bool False
#     order              int64 1
#     start              <U10 '2012-01-01'
#     stop               <U10 '2012-01-03'
#     test_start         <U10 '2012-03-01'
#     test_stop          <U10 '2012-03-03'
#     bias               bool False
#     W1                 (latitude, longitude) float64 ...
#     mse                (latitude, longitude) float64 ...
#     r2                 (latitude, longitude) float64 ...
#     ase                (latitude, longitude) float64 ...
#     num_train_samples  (latitude, longitude) float64 ...
#     num_test_samples   (latitude, longitude) float64 ...
#     global_mse         float64 ...
# ...

# %%
m1 = AR_model_loader().load_model_to_xarray('/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T11:13:41.nc')
fig, axes = plt.subplots(1, 1)
m1['r2'].plot(ax = axes)
#m1['bias'].plot(ax = axes[1])
plt.savefig('/home/hanna/MS-thesis/python_figs/test_wv_transform_sigmoidFalse.png')

# %%
m1['mse']
# Out:
# <xarray.DataArray 'mse' (latitude: 81, longitude: 161)>
# array([[1.163904, 1.070711, 1.117344, ..., 0.90799 , 0.862563, 0.866408],
#        [1.071049, 1.132057, 1.180253, ..., 0.823263, 0.781131, 0.8007  ],
#        [1.008546, 1.072947, 1.161892, ..., 0.906726, 0.707719, 0.927571],
#        ...,
#        [1.2854  , 1.286018, 1.309404, ..., 2.055166, 2.217642, 2.341109],
#        [1.401676, 1.314229, 1.323964, ..., 2.052423, 2.121655, 2.412131],
#        [1.470408, 1.562265, 1.405625, ..., 2.555886, 2.26046 , 2.188323]])
# Coordinates:
#   * longitude  (longitude) float64 -15.0 -14.75 -14.5 -14.25 ... 24.5 24.75 25.0
#   * latitude   (latitude) float64 30.0 30.25 30.5 30.75 ... 49.5 49.75 50.0

# %%
m1 = AR_model_loader().load_model_to_xarray('/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T10:00:59.nc')
fig, axes = plt.subplots(1, 1)
m1['r2'].plot(ax = axes)
#m1['bias'].plot(ax = axes[1])
plt.savefig('/home/hanna/MS-thesis/python_figs/test2_wv_transform_sigmoidFalse.png')

# %%
fil = '/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T19:25:28.nc'
m1 = AR_model_loader().load_model_to_xarray(fil)
fig, axes = plt.subplots(1, 1)
m1['r2'].plot(ax = axes)
#m1['bias'].plot(ax = axes[1])
plt.savefig('/home/hanna/MS-thesis/python_figs/test3_wv_transform_sigmoidFalse.png')

# %%
fil = '/home/hanna/lagrings/results/ar/AR_traditional2020-05-11T17:28:25.nc'
m1 = AR_model_loader().load_model_to_xarray(fil)

# %%
m1['r2']
# Out:
# <xarray.DataArray 'r2' (latitude: 81, longitude: 161)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Coordinates:
#   * longitude  (longitude) float64 -15.0 -14.75 -14.5 -14.25 ... 24.5 24.75 25.0
#   * latitude   (latitude) float64 30.0 30.25 30.5 30.75 ... 49.5 49.75 50.0

# %%
fig, axes = plt.subplots(1, 1)
m1['r2'].plot(ax = axes)
#m1['bias'].plot(ax = axes[1])
plt.savefig('/home/hanna/MS-thesis/python_figs/test4_wv_transform_sigmoidFalse.png')

# %%
fig, axes = plt.subplots(1, 2)
m1['W1'].plot(ax = axes[0])
m1['bias'].plot(ax = axes[1])
plt.savefig('/home/hanna/MS-thesis/python_figs/test_traditional_ar_weights.png')
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

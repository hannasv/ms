# %%
from sclouds.ml.regression.AR_model import AR_model

# %%
m = AR_model(start = '2012-01-01',      stop = '2012-01-03',
             test_start = '2012-03-01', test_stop = '2012-03-03',
             order = 1,                 transform = True,        
             sigmoid = False)
# Out:
# Num files 5

# %%
coeff = m.fit()
# Out:
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# Detected 72 samples.
# (71, 5)
# (71, 1)
# ...

# %%
m.save()

# %%
m.coeff_matrix.shape

# %%
from sclouds.ml.regression.AR_model import AR_model
m2    = AR_model(start = '2012-01-01', stop = None,
                 # test_start = '2012-03-01', test_stop = '2012-03-31',
                 order = 0, transformer = True, sigmoid = False)
coeff = m2.fit()
m2.save()

# %%
from sclouds.ml.regression.AR_model import AR_model
m2    = AR_model(start = '2012-01-01', stop = None,
                 test_start = '2012-03-01', #test_stop = '2012-03-31',
                 order = 0, transformer = True, sigmoid = False)
coeff = m2.fit()
m2.save()

# %%
m2.get_configuration()

# %%
from sclouds.ml.regression.AR_model import AR_model
m3    = AR_model(start = '2012-01-01', stop ='2012-01-03', 
                 test_start = '2012-03-01', test_stop = '2012-03-31',
                 order = 1, transform = False, sigmoid = False)
coeff = m3.fit()
m3.save()
# Out:
# Num files 5
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# (71, 1)
# Detected 72 samples.
# (71, 6)
# ...

# %%
m3.get

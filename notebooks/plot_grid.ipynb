# %%
#!pip install cartopy

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import numpy as np
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import glob
import seaborn as sns
import xarray as xr

# %%
# NOT USE THIS 
ax = plt.axes(projection=ccrs.TransverseMercator())
ax.coastlines()
ax.gridlines()
ax.set_extent([-15, 40, 30, 60])
#gl = ax.gridlines(crs=ccrs.TransverseMercator(central_longitude=0.0, central_latitude=0.0, false_easting=0.0, false_northing=0.0, scale_factor=1.0), draw_labels=True,
#                  linewidth=2, color='gray', alpha=0.5, linestyle='--')

# %%
# Eumetsat 36 000km.
import cartopy as cp
ax = plt.axes(projection=ccrs.Geostationary(central_longitude=0.0, satellite_height=35785831, 
                   false_easting=0, false_northing=0, globe=None))
ax.coastlines()
ax.gridlines(color='black', alpha=0.5)
ax.add_feature(cp.feature.OCEAN, zorder=0)
ax.add_feature(cp.feature.LAND, zorder=0, edgecolor='black')
ax.set_extent([-15, 29.25, 30, 55.25-0.75])
ax.set_title('Domain')
# Out:
# Text(0.5,1,'Domain')

# %% [markdown]
# Resolution in era interim files. Lets do this for

# %%
np.arange(-15, 30, 0.75) # len 60
# Out:
# array([-15.  , -14.25, -13.5 , -12.75, -12.  , -11.25, -10.5 ,  -9.75,
#         -9.  ,  -8.25,  -7.5 ,  -6.75,  -6.  ,  -5.25,  -4.5 ,  -3.75,
#         -3.  ,  -2.25,  -1.5 ,  -0.75,   0.  ,   0.75,   1.5 ,   2.25,
#          3.  ,   3.75,   4.5 ,   5.25,   6.  ,   6.75,   7.5 ,   8.25,
#          9.  ,   9.75,  10.5 ,  11.25,  12.  ,  12.75,  13.5 ,  14.25,
#         15.  ,  15.75,  16.5 ,  17.25,  18.  ,  18.75,  19.5 ,  20.25,
#         21.  ,  21.75,  22.5 ,  23.25,  24.  ,  24.75,  25.5 ,  26.25,
#         27.  ,  27.75,  28.5 ,  29.25])

# %%
# Resolution 60 in longitudinal direction.
len(np.arange(-15, 30, 0.75))
# Out:
# 60

# %%
# Resolutional 35 cells in latitudinal direction 
len(np.arange(30, 56, 0.75))
# Out:
# 35

# %%
np.arange(30, 56, 0.75)
# Out:
# array([30.  , 30.75, 31.5 , 32.25, 33.  , 33.75, 34.5 , 35.25, 36.  ,
#        36.75, 37.5 , 38.25, 39.  , 39.75, 40.5 , 41.25, 42.  , 42.75,
#        43.5 , 44.25, 45.  , 45.75, 46.5 , 47.25, 48.  , 48.75, 49.5 ,
#        50.25, 51.  , 51.75, 52.5 , 53.25, 54.  , 54.75, 55.5 ])

# %%
ax = plt.axes(projection=ccrs.Geostationary(central_longitude=0.0, satellite_height=35785831, 
                   false_easting=0, false_northing=0, globe=None))
ax.coastlines()
ax.gridlines(color='black', alpha=0.5)
ax.add_feature(cp.feature.OCEAN, zorder=0)
ax.add_feature(cp.feature.LAND, zorder=0, edgecolor='black')
ax.set_extent([-15, 42, 30, 75])
ax.set_title('Europe viewed from 0 degree service')
plt.savefig("Europed_view.png")

# %%
era_path = '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/'

# %%
files = glob.glob(era_path + "*all*.nc")
files
# Out:
# ['/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all_cropped_DJF.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all_cropped_JJA.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all_cropped_MAM.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all_cropped_DJF.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all_cropped_JJA.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all_cropped_MAM.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all_cropped_DJF.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all_cropped_JJA.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all_cropped_MAM.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all_cropped_DJF.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all_cropped_JJA.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all_cropped_MAM.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all_cropped_DJF.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all_cropped_JJA.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all_cropped_MAM.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all_cropped_SON.nc']

# %%
cropped_files = glob.glob(era_path + "*cropped.nc")

# %%
cropped_files
# Out:
# ['/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all_cropped.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all_cropped.nc']

# %%
# crop_nc_file(fil, fil[:-3]+"_cropped.nc")
def create_seasonal_files(infile):
    W = xr.open_dataset(infile)
    for i, season in enumerate(W.groupby('time.season')):
        key, dataset = season
        outfile = infile[:-3]+"_{}.nc".format(key)
        dataset.to_netcdf(path = outfile)
        #cropped.to_netcdf(path = outfile)
    return

# %%
for infile in cropped_files:
    create_seasonal_files(infile)

# %%
son_files = glob.glob(era_path + "*SON.nc")

# %%
son_files
# Out:
# ['/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_q_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_tcc_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_t2m_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_r_all_cropped_SON.nc',
#  '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/raw_1979-01-01_2018-12-31_sp_all_cropped_SON.nc']

# %%
import xarray as xr

# %%
start = "2012-01-01"
stop = "2013-01-01"

# %%
np.shape(xr.open_dataset(son_files[0]).sel(time = slice(start, stop)).q.values[0,:,:])
# Out:
# (35, 60)

# %%
def create_ML_repo(start = "2012-01-01", stop = "2013-01-01", season = "SON", 
                  era_path = '/uio/lagringshotell/geofag/students/metos/hannasv/era_interim_data/'):
    """
    Want all year put season to "".
    """
    q   = xr.open_dataset(glob.glob(era_path + "*_q_*" + season +".nc")[0]).q.values
    r   = xr.open_dataset(glob.glob(era_path + "*_r_*"+ season +".nc")[0]).r.values
    tcc = xr.open_dataset(glob.glob(era_path + "*tcc*"+ season +".nc")[0]).tcc.values
    sp  = xr.open_dataset(glob.glob(era_path + "*sp*"+ season +".nc")[0]).sp.values
    t2m = xr.open_dataset(glob.glob(era_path + "*t2m*"+ season +".nc")[0]).t2m.values
    assert np.shape(q) == np.shape(r) == np.shape(tcc) == np.shape(sp) == np.shape(t2m)
    
    nbr_times, nbr_lats, nbr_lon = np.shape(q)
    train = []
    true  = tcc
    for i in range(nbr_times):
        one_timestep = np.array([q[i], r[i], tcc[i], t2m[i] ])
        #print(one_timestep.shape)
        train.append(one_timestep)
    return np.array(train), true

# %%
train, test = create_ML_repo()

# %%
train.shape, test.shape
# Out:
# ((2184, 4, 35, 60), (2184, 35, 60))

# %%
for f in cropped_files:
    
    W = xr.open_dataset(f)
    variable = f.split('_')[-3] 
    fig, axes = plt.subplots(2,2)
    fig.set_size_inches(11,8)
    fig.suptitle(variable)

    axes = axes.flatten()
    #print((ax1, ax2, ax3, ax4))
    for i, season in enumerate(W.groupby('time.season')):
        key, dataset = season
        #print(dataset.mean('time')[variable].values)
        sns.heatmap(dataset.mean('time')[variable].values, ax = axes[i])
        axes[i].set_title(key)
        plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2)

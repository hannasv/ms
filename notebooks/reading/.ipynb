# %%
import glob
import xarray as xr
from netCDF4 import Dataset

# %%
blabla = "/home/hanna/temp_coords/archive.eumetsat.int/umarf/onlinedownload/hannasv/1364854/"

# %%
glob.glob(blabla + "*.nc")
# Out:
# ['/home/hanna/temp_coords/archive.eumetsat.int/umarf/onlinedownload/hannasv/1364854/W_XX-EUMETSAT-Darmstadt,SING+LEV+SAT,MSG1+CLM_C_EUMG_20070310054500.nc',
#  '/home/hanna/temp_coords/archive.eumetsat.int/umarf/onlinedownload/hannasv/1364854/W_XX-EUMETSAT-Darmstadt,SING+LEV+SAT,MSG2+CLM_C_EUMG_20070310054500.nc']

# %%
d1 = Dataset('/home/hanna/temp_coords/archive.eumetsat.int/umarf/onlinedownload/hannasv/1364854/W_XX-EUMETSAT-Darmstadt,SING+LEV+SAT,MSG1+CLM_C_EUMG_20070310054500.nc')

# %%
d1lat = d1.variables['lat'][:].data

# %%
d1lon = d1.variables['lon'][:].data

# %%
d2 = Dataset('/home/hanna/temp_coords/archive.eumetsat.int/umarf/onlinedownload/hannasv/1364854/W_XX-EUMETSAT-Darmstadt,SING+LEV+SAT,MSG2+CLM_C_EUMG_20070310054500.nc')

# %%
d2lat = d2.variables['lat'][:].data

# %%
d2lon = d2.variables['lon'][:].data

# %%
import seaborn as sns

# %%
sns.heatmap(d2lat - d1lat)

# %%
sns.heatmap(d2lon - d1lon)

# %%
c1 = d1.variables['cloudMask'][:].data
c2 = d2.variables['cloudMask'][:].data

# %%
sns.heatmap(c1-c2)

# %%
sns.heatmap(c1)

# %%
sns.heatmap(c2)

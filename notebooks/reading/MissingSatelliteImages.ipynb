# %%
import glob

import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#sat_dir = '/uio/lagringshotell/geofag/projects/miphclac/hannasv/'
sat_dir = '/home/hanna/miphclac/'

# %%
sat_files = glob.glob(os.path.join(sat_dir, '*.grb'))

# %%
len(sat_files)
# Out:
# 0

# %% [markdown]
# # Find list of files which needs to be renamed.
# ## Think of a condition.

# %%
sort = np.sort(sat_files)

# %%
sort[:3]
# Out:
# array([], dtype=float64)

# %%
def timestamp(filename):
    """
    Returns the numpy datetime 64 [ns] for the current date.
    This is a bit hardcoded at the moment ....
    """
    splits = filename.split('-')
    ts = splits[5]
    year = ts[:4]
    month = ts[4:6]
    day = ts[6:8]
    hr = ts[8:10]
    minuts = ts[10:12]
    sek = ts[12:14]
    # TODO make sure all filenames have seconds
    return np.datetime64( year+"-"+month+"-"+day+"T"+hr ) # +":"+minuts+":"+sek

# %%
all_ts = []

for fil in sort:
    all_ts.append(timestamp(fil))

# %%
plt.plot(all_ts)
plt.show()

# %%
ll = np.sort(all_ts)
plt.plot(ll)
plt.show()

# %% [markdown]
# # Print times that are missing

# %%
all_ = np.arange('2004-04-02T00:00:00', '2019-01-01T00:00:00', dtype='datetime64[h]')

# %%
missing = []
for ts in all_:
    if ts not in ll:
        missing.append(ts)
# Out:
# /home/hanna/anaconda3/envs/sciclouds/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(missing)

# %%
single = []
period = []

for i in range(len(missing)-1):
    if i == 0:
        diff = (missing[i+1] - missing[i]).astype(int)
        if diff == 1:
            serie = True
            series_str = "{}".format(missing[i]) # add last one later 
        else:
            serie = False
            single.append(missing[i])
    else: 
        if serie:
            diff_f = (missing[i+1] - missing[i]).astype(int)
            #diff_b = (missing[i] - missing[i-1]).astype(int)
            #print(diff_f)
            #print(diff_b)
            if diff_f == 1: # == diff_b 
                # part of serie --> don't store.
                serie = True
                #print('never enters')
            else:
                # Slutten på en serie.
                serie = False
                series_str += "-{}".format(missing[i])
                period.append(series_str)
        else:
            # Sjekk om det er begynnelsen på en serie.
            diff = (missing[i+1] - missing[i]).astype(int)
            if diff == 1:
                serie = True
                series_str = "{}".format(missing[i]) # add last one later 
            else:
                serie = False
                single.append(missing[i])

single.append(missing[-1])

# %%
single
# Out:
# [numpy.datetime64('2004-04-07T12','h'),
#  numpy.datetime64('2004-04-08T15','h'),
#  numpy.datetime64('2004-04-28T21','h'),
#  numpy.datetime64('2004-05-03T11','h'),
#  numpy.datetime64('2004-05-06T15','h'),
#  numpy.datetime64('2004-05-08T10','h'),
#  numpy.datetime64('2004-05-08T19','h'),
#  numpy.datetime64('2004-05-10T08','h'),
#  numpy.datetime64('2004-05-11T15','h'),
#  numpy.datetime64('2004-06-08T12','h'),
#  numpy.datetime64('2004-06-17T08','h'),
#  numpy.datetime64('2004-06-17T14','h'),
#  numpy.datetime64('2004-06-17T17','h'),
#  numpy.datetime64('2004-06-30T09','h'),
#  numpy.datetime64('2004-07-18T13','h'),
#  numpy.datetime64('2004-07-20T15','h'),
#  numpy.datetime64('2004-07-23T18','h'),
#  numpy.datetime64('2004-07-27T22','h'),
#  numpy.datetime64('2004-08-17T11','h'),
#  numpy.datetime64('2004-08-20T08','h'),
#  numpy.datetime64('2004-08-23T19','h'),
#  numpy.datetime64('2004-10-12T22','h'),
#  numpy.datetime64('2004-10-13T08','h'),
#  numpy.datetime64('2004-11-03T09','h'),
#  numpy.datetime64('2004-11-16T19','h'),
#  numpy.datetime64('2004-12-09T10','h'),
#  numpy.datetime64('2005-02-03T13','h'),
#  numpy.datetime64('2005-02-03T15','h'),
#  numpy.datetime64('2005-02-03T22','h'),
#  numpy.datetime64('2005-02-23T14','h'),
#  numpy.datetime64('2005-02-27T13','h'),
#  numpy.datetime64('2005-03-12T18','h'),
#  numpy.datetime64('2005-03-14T13','h'),
#  numpy.datetime64('2005-03-18T14','h'),
#  numpy.datetime64('2005-03-24T09','h'),
#  numpy.datetime64('2005-04-01T09','h'),
#  numpy.datetime64('2005-04-07T07','h'),
#  numpy.datetime64('2005-04-21T09','h'),
#  numpy.datetime64('2005-04-26T14','h'),
#  numpy.datetime64('2005-05-02T09','h'),
#  numpy.datetime64('2005-05-29T07','h'),
#  numpy.datetime64('2005-06-16T14','h'),
#  numpy.datetime64('2005-06-21T13','h'),
#  numpy.datetime64('2005-06-21T18','h'),
#  numpy.datetime64('2005-06-25T17','h'),
#  numpy.datetime64('2005-06-30T11','h'),
#  numpy.datetime64('2005-07-15T00','h'),
#  numpy.datetime64('2005-07-15T16','h'),
#  numpy.datetime64('2005-07-21T10','h'),
#  numpy.datetime64('2005-10-10T12','h'),
#  numpy.datetime64('2005-10-12T12','h'),
#  numpy.datetime64('2005-10-27T08','h'),
#  numpy.datetime64('2005-11-08T10','h'),
#  numpy.datetime64('2005-12-09T10','h'),
#  numpy.datetime64('2005-12-23T11','h'),
#  numpy.datetime64('2006-02-02T00','h'),
#  numpy.datetime64('2006-09-08T02','h'),
#  numpy.datetime64('2006-12-07T13','h'),
#  numpy.datetime64('2006-12-15T09','h'),
#  numpy.datetime64('2007-03-03T13','h'),
#  numpy.datetime64('2007-09-08T00','h'),
#  numpy.datetime64('2007-09-10T18','h'),
#  numpy.datetime64('2007-09-17T01','h'),
#  numpy.datetime64('2007-10-11T12','h'),
#  numpy.datetime64('2007-10-17T08','h'),
#  numpy.datetime64('2007-10-25T16','h'),
#  numpy.datetime64('2008-02-12T14','h'),
#  numpy.datetime64('2008-04-09T10','h'),
#  numpy.datetime64('2008-05-19T12','h'),
#  numpy.datetime64('2008-05-20T11','h'),
#  numpy.datetime64('2008-06-10T09','h'),
#  numpy.datetime64('2008-06-24T08','h'),
#  numpy.datetime64('2009-10-11T12','h'),
#  numpy.datetime64('2009-10-12T12','h'),
#  numpy.datetime64('2011-02-21T12','h'),
#  numpy.datetime64('2011-02-28T13','h'),
#  numpy.datetime64('2011-03-01T12','h'),
#  numpy.datetime64('2011-03-17T06','h'),
#  numpy.datetime64('2011-10-12T12','h'),
#  numpy.datetime64('2011-10-13T12','h'),
#  numpy.datetime64('2011-10-14T12','h'),
#  numpy.datetime64('2011-12-04T10','h'),
#  numpy.datetime64('2012-02-08T09','h'),
#  numpy.datetime64('2012-02-08T11','h'),
#  numpy.datetime64('2012-06-19T00','h'),
#  numpy.datetime64('2012-09-24T11','h'),
#  numpy.datetime64('2013-02-24T06','h'),
#  numpy.datetime64('2013-07-05T00','h'),
#  numpy.datetime64('2013-07-09T10','h'),
#  numpy.datetime64('2014-01-14T10','h'),
#  numpy.datetime64('2014-06-03T10','h'),
#  numpy.datetime64('2014-11-04T10','h'),
#  numpy.datetime64('2014-11-17T10','h'),
#  numpy.datetime64('2015-02-19T02','h'),
#  numpy.datetime64('2015-03-03T09','h'),
#  numpy.datetime64('2015-04-22T09','h'),
#  numpy.datetime64('2015-04-28T03','h'),
#  numpy.datetime64('2015-04-28T08','h'),
#  numpy.datetime64('2015-04-28T12','h'),
#  numpy.datetime64('2016-12-31T05','h'),
#  numpy.datetime64('2017-01-19T09','h'),
#  numpy.datetime64('2018-11-08T13','h'),
#  numpy.datetime64('2018-11-19T10','h')]

# %%
period
# Out:
# ['2004-04-07T02-2004-04-07T07',
#  '2004-05-08T12-2004-05-08T16',
#  '2004-06-14T12-2004-06-14T13',
#  '2004-06-23T05-2004-06-23T06',
#  '2004-08-26T02-2004-08-26T03',
#  '2004-09-29T01-2004-09-29T02',
#  '2004-10-04T07-2004-10-07T10',
#  '2004-11-08T13-2004-11-08T14',
#  '2004-12-03T02-2004-12-03T04',
#  '2004-12-08T06-2004-12-08T07',
#  '2004-12-16T14-2004-12-16T15',
#  '2005-01-10T13-2005-01-14T10',
#  '2005-02-03T17-2005-02-03T18',
#  '2005-03-06T12-2005-03-06T14',
#  '2005-03-06T16-2005-03-06T17',
#  '2005-03-15T11-2005-03-15T12',
#  '2005-04-18T03-2005-04-18T13',
#  '2005-05-27T00-2005-05-27T03',
#  '2005-05-27T16-2005-05-27T17',
#  '2005-06-20T12-2005-06-20T13',
#  '2005-06-20T19-2005-06-20T21',
#  '2005-09-14T12-2005-09-14T13',
#  '2006-01-09T13-2006-01-13T08',
#  '2006-03-01T00-2006-08-31T23',
#  '2006-09-04T13-2006-09-04T15',
#  '2006-09-23T14-2006-09-25T06',
#  '2007-03-07T00-2007-03-07T01',
#  '2007-03-10T06-2007-03-10T08',
#  '2007-04-02T00-2007-08-31T23',
#  '2007-11-17T06-2007-11-17T08',
#  '2007-11-19T06-2007-11-19T07',
#  '2008-05-05T08-2008-05-05T13',
#  '2008-05-13T22-2008-05-14T00',
#  '2008-05-19T09-2008-05-19T10',
#  '2008-05-20T05-2008-05-20T06',
#  '2008-08-01T00-2009-09-03T23',
#  '2009-11-02T09-2009-11-02T10',
#  '2010-01-01T00-2010-04-30T23',
#  '2010-09-02T00-2011-01-31T23',
#  '2011-03-16T20-2011-03-16T22',
#  '2012-04-04T14-2012-04-04T15',
#  '2012-04-16T21-2012-04-16T22',
#  '2012-06-25T11-2012-06-25T12',
#  '2012-08-22T19-2012-08-22T20',
#  '2012-08-31T01-2012-08-31T04',
#  '2013-06-18T09-2013-06-18T10',
#  '2013-08-18T08-2013-08-18T14',
#  '2013-08-31T00-2013-12-31T23',
#  '2014-03-09T05-2014-03-09T09',
#  '2014-06-12T06-2014-06-12T07',
#  '2015-01-11T07-2015-01-11T08',
#  '2015-01-11T12-2015-01-11T13',
#  '2015-02-08T00-2015-02-08T02',
#  '2015-03-12T11-2015-03-12T13',
#  '2015-07-01T00-2015-07-01T01',
#  '2015-08-02T00-2016-12-30T23',
#  '2017-05-02T00-2018-08-31T23',
#  '2018-10-18T15-2018-10-18T16']

# %% [markdown]
# # OLD

# %%
tot = np.arange('2004-04-02T00:00:00', '2019-01-01T00:00:00', dtype='datetime64[h]')
ll = np.sort(all_ts)

period = []
missing_periods = []
missing_singles = []

j=0
i = 0

while j < len(tot) and i < len(ll):
    #exp_ts = 
    period = (ll[i] - tot[j]).astype(int)
    #len_period = diff.astype(int)
    if period == 0:
        print("only updates values")
        j+=1
        i+=1
    else:
        #print(" Detected singles {} for len {}".format( exp_ts , len_period ))
        
        if np.abs(len_period) > 1:
            print(" Detected new period {}".format(tuple( (tot[j] , tot[j+np.abs(len_period)]) )))
            missing_dates.append( tuple( (tot[j] , tot[j+np.abs(len_period)]) ))
            j = j+np.abs(len_period)
        else:        
            missing_singles.append(exp_ts)
            j+=1

    i += 1    
    #print(" Index_true = {} j = {}".format(index_true, j))
# Out:
# only updates values

# %%
missing_dates
# Out:
# [(numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
# ...
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  (numpy.datetime64('2004-04-02T00','h'),
#   numpy.datetime64('2004-04-02T00','h')),
#  ...]

# %%
missing_singles
# Out:
# [numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  numpy.datetime64('2004-04-02T00','h'),
#  ...]

# %%
expected_ts = np.arange('2004-04-02T00:00:00', '2018-12-31T23:00:00', dtype='datetime64[h]')

# %%
expected_ts[:10]
# Out:
# array(['2004-04-02T00', '2004-04-02T01', '2004-04-02T02', '2004-04-02T03',
#        '2004-04-02T04', '2004-04-02T05', '2004-04-02T06', '2004-04-02T07',
#        '2004-04-02T08', '2004-04-02T09'], dtype='datetime64[h]')

# %%
for start, stop, length in zip(period_start, period_stop, length_of_periods):
    print("{}-{}, number of hours {}".format(start, stop, length ))

# %%
for i, this_hr in enumerate(ll):
    next_hr = this_hr + np.timedelta64(1, 'h')
    prev_hr = this_hr - np.timedelta64(1, 'h')
    
    if 
    
    if i < len(ll)-1: # IF NOT LAST
        
        # test if its a part of a sequence
        
        
        # if not add to the sigle array 
        if ll[i+1] != next_hr:
            missing.append(next_hr)

# %%
len(missing)

# %%
plt.plot(missing)

# %%
missing[:100]

# %%
missing[100:200]

# %%
missing[200:300]

# %%
missing[400:600]

# %%
missing[600:800]

# %%
missing[800:1000]

# %%
missing[1200:1400]

# %%
missing[2200:2800]

# %%
missing[3600:4200]

# %%
import xarray as xr

# %%
filll = '/uio/lagringshotell/geofag/students/metos/hannasv/satelite_data/*.nc'

# %%
files = glob.glob(filll)

# %%
for fil in files:
    print(xr.open_dataset(fil))

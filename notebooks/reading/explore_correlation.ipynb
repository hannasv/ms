# %%
# 
import numpy as np
import xarray as xr
import os 
import glob

# %%
glob.glob('/home/hanna/lagrings/results/stats/monthly_mean/*nc')
# Out:
# ['/home/hanna/lagrings/results/stats/monthly_mean/monthly_means.nc',
#  '/home/hanna/lagrings/results/stats/monthly_mean/correlation_sp.nc',
#  '/home/hanna/lagrings/results/stats/monthly_mean/correlation.nc',
#  '/home/hanna/lagrings/results/stats/monthly_mean/monthly_means_updated.nc',
#  '/home/hanna/lagrings/results/stats/monthly_mean/correlation_updated.nc']

# %%
#file = '/home/hanna/miphclac/2004_07/2004_07_tcc.nc'
file = '/home/hanna/lagrings/satelite_coordinates/2009_05_tcc_regridded_masks.nc'
data = xr.open_dataset(file)

# %%
subset = data.isel(time = 0)
subset['tcc'].plot()

# %%
subset = data.isel(time = 15)
subset['tcc'].plot()

# %%
subset = data.isel(time = 35)
subset['tcc'].plot()

# %%
str(subset.time.values)[:19]
# Out:
# '2009-05-02T11:00:00'

# %%
fil = '/home/hanna/lagrings/results/stats/monthly_mean/correlation_in_time.nc'

VARIABLES = ['r', 'q', 't2m', 'sp']
n_rows = len(VARIABLES)
n_cols = 1

data = xr.open_dataset(fil)
print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/final/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     197             try:
# --> 198                 file = self._cache[self._key]
#     199             except KeyError:
#
# ~/anaconda3/envs/final/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/hanna/lagrings/results/stats/monthly_mean/correlation_in_time.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
data['t2m'].plot()

# %%
data['sp'].plot()

# %%
data['q'].plot()

# %%
data['r'].plot()

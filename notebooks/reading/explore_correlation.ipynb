# %%
# 
import numpy as np
import xarray as xr
import os 
import glob

# %%
fil = '/home/hanna/lagrings/results/stats/monthly_mean/correlation.nc'

VARIABLES = ['r', 'q', 't2m', 'sp']
n_rows = len(VARIABLES)
n_cols = 1

data = xr.open_dataset(fil)
print(data)
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 81, longitude: 161)
# Coordinates:
#   * longitude  (longitude) float64 -15.0 -14.75 -14.5 -14.25 ... 24.5 24.75 25.0
#   * latitude   (latitude) float64 30.0 30.25 30.5 30.75 ... 49.5 49.75 50.0
# Data variables:
#     r          (latitude, longitude) float64 ...
#     q          (latitude, longitude) float64 ...
#     t2m        (latitude, longitude) float64 ...
#     sp         (latitude, longitude) float64 ...

# %%
data['t2m']
# Out:
# <xarray.DataArray 't2m' (latitude: 81, longitude: 161)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Coordinates:
#   * longitude  (longitude) float64 -15.0 -14.75 -14.5 -14.25 ... 24.5 24.75 25.0
#   * latitude   (latitude) float64 30.0 30.25 30.5 30.75 ... 49.5 49.75 50.0

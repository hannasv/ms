# %%
import glob
import os

import numpy as np

from sclouds.helpers import path_input

# %%
def get_list_of_files(start = '2012-01-01', stop = '2012-01-31', include_start = True, include_stop = True):
    """ Returns list of files containing data for the requested period.

    Parameteres
    ----------------------
    start : str
        Start of period. First day included. (default '2012-01-01')

    stop : str
        end of period. Last day included. (default '2012-01-31')

    Returns
    -----------------------
    subset : List[str]
        List of strings containing all the absolute paths of files containing
        data in the requested period.
    """
    # Remove date.
    parts = start.split('-')
    start_search_str = '{}_{:02d}'.format(parts[0], int(parts[1]))

    if stop is not None:
        parts = stop.split('-')
        stop_search_str = '{}_{:02d}'.format(parts[0], int(parts[1]))
    else:
        stop_search_str = ''

    if (start_search_str == stop_search_str) or (stop is None):
        subset = glob.glob(os.path.join( path_input, '{}*.nc'.format(start_search_str)))
    else:
        # get all files
        files = glob.glob(os.path.join( path_input, '*.nc' ))
        files = np.sort(files) # sorting then for no particular reson
        
        if include_start and include_stop:
            min_fil = os.path.join(path_input, start_search_str + '_q.nc')
            max_fil = os.path.join(path_input, stop_search_str + '_tcc.nc')
            
            smaller = files[files <= max_fil]
            subset  = smaller[smaller >= min_fil] # results in all the files
            
        elif include_start and not include_stop:
            min_fil = os.path.join(path_input, start_search_str + '_q.nc')
            max_fil = os.path.join(path_input, stop_search_str + '_q.nc')
            
            smaller = files[files < max_fil]
            subset  = smaller[smaller >= min_fil] # results in all the files

        elif not include_start and include_stop:
            min_fil = os.path.join(path_input, start_search_str + '_tcc.nc')
            print('detected min fil {}'.format(min_fil))
            max_fil = os.path.join(path_input, stop_search_str + '_tcc.nc')
            
            smaller = files[files <= max_fil]
            subset  = smaller[smaller > min_fil] # results in all the files
        else:
            raise ValueError('Something wierd happend. ')
        
    #assert len(subset)%5==0, "Not five of each files, missing variables in file list!"
    #assert len(subset)!=0, "No files found, check if you have mounted lagringshotellet."

    return subset

# %% [markdown]
# ## Check files in period before

# %%
def get_list_of_files_excluding_period(start = '2012-01-01', stop = '2012-01-31'):
    
    first_period = get_list_of_files(start = '2004-04-01', stop = start, include_start = True, include_stop = False)
    last_period = get_list_of_files(start = stop, stop = '2018-12-31', include_start = False, include_stop = True)
    #print(first_period)
    print(last_period)
    entire_period = list(first_period) + list(last_period)
    return entire_period

# %%
#files = get_list_of_files_excluding_period(start = '2009-01-01', stop = '2013-12-31')
# Out:
# detected min fil /home/hanna/lagrings/ERA5_monthly/2013_12_tcc.nc
# ['/home/hanna/lagrings/ERA5_monthly/2014_01_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_01_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_01_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_01_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_01_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_02_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_02_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_02_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_02_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_02_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_03_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_03_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_03_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_03_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_03_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_04_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_04_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_04_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_04_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_04_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_05_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_05_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_05_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_05_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_05_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_06_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_06_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_06_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_06_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_06_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_07_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_07_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_07_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_07_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_07_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_08_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_08_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_08_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_08_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_08_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_09_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_09_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_09_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_09_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_09_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_10_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_10_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_10_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_10_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_10_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_11_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_11_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_11_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_11_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_11_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_12_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_12_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_12_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_12_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2014_12_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_01_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_01_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_01_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_01_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_01_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_02_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_02_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_02_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_02_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_02_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_03_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_03_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_03_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_03_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_03_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_04_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_04_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_04_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_04_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_04_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_05_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_05_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_05_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_05_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_05_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_06_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_06_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_06_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_06_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_06_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_07_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_07_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_07_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_07_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_07_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_08_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_08_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_08_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_08_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_08_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_09_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_09_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_09_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_09_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_09_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_10_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_10_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_10_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_10_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_10_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_11_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_11_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_11_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_11_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_11_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_12_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_12_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_12_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_12_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2015_12_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_01_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_01_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_01_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_01_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_01_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_02_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_02_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_02_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_02_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_02_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_03_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_03_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_03_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_03_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_03_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_04_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_04_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_04_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_04_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_04_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_05_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_05_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_05_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_05_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_05_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_06_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_06_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_06_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_06_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_06_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_07_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_07_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_07_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_07_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_07_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_08_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_08_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_08_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_08_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_08_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_09_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_09_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_09_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_09_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_09_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_10_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_10_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_10_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_10_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_10_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_11_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_11_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_11_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_11_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_11_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_12_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_12_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_12_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_12_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2016_12_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_01_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_01_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_01_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_01_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_01_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_02_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_02_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_02_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_02_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_02_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_03_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_03_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_03_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_03_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_03_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_04_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_04_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_04_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_04_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_04_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_05_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_05_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_05_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_05_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_05_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_06_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_06_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_06_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_06_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_06_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_07_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_07_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_07_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_07_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_07_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_08_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_08_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_08_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_08_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_08_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_09_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_09_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_09_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_09_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_09_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_10_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_10_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_10_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_10_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_10_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_11_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_11_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_11_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_11_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_11_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_12_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_12_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_12_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_12_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2017_12_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_01_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_01_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_01_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_01_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_01_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_02_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_02_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_02_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_02_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_02_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_03_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_03_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_03_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_03_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_03_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_04_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_04_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_04_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_04_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_04_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_05_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_05_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_05_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_05_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_05_tcc.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_06_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_06_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_06_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_06_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_07_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_07_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_07_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_07_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_08_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_08_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_08_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_08_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_09_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_09_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_09_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_09_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_10_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_10_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_10_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_10_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_11_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_11_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_11_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_11_t2m.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_12_q.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_12_r.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_12_sp.nc'
#  '/home/hanna/lagrings/ERA5_monthly/2018_12_t2m.nc']

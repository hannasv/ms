# %%
## Read statistics

# %%
read_dir   = '/home/hanna/lagrings/ERA5_monthly/'
save_dir   = '/home/hanna/lagrings/ERA5_stats/results/'
save_dir   = '/home/hanna/lagrings/results/stats/'
filter_dir = '/home/hanna/MS-suppl/'

# for wessel -- /uio/lagringshotell/geofag/students/metos/hannasv/results
#read_dir   = '/uio/lagringshotell/geofag/students/metos/hannasv/ERA5_monthly/'
#save_dir   = '/uio/lagringshotell/geofag/students/metos/hannasv/results/stats/'
#filter_dir = '/uio/hume/student-u89/hannasv/MS-suppl/'

STATS         = ['mean', 'std', 'min', 'max', 'median'] # 'median',
VALID_VARS    = ['r', 'q', 't2m', 'sp', 'tcc']
VALID_FILTERS = ['coast', 'sea', 'land', 'artefact', 'all', 'land_mask']

# %%
import os
import glob
import xarray as xr

# %%
files = glob.glob(os.path.join( save_dir, '*pixel*.nc' ))

# %%
files
# Out:
# ['/home/hanna/lagrings/results/stats/stats_pixel_q_all.nc',
#  '/home/hanna/lagrings/results/stats/stats_pixel_r_all.nc',
#  '/home/hanna/lagrings/results/stats/stats_pixel_t2m_all.nc',
#  '/home/hanna/lagrings/results/stats/stats_pixel_sp_all.nc',
#  '/home/hanna/lagrings/results/stats/stats_pixel_tcc_all.nc']

# %%
data = xr.open_dataset(files[4])

# %%
data['min'].plot() # dette er en konsekvens av regridding schemet .....

# %%
data['max'].plot() # alle pixler har skyer over hele

# %%
data['mean'].plot()

# %%
data['std'].plot()

# %%
data['median'].plot()

# %%
#data['mad'].plot()

# %%
# Legg inn typetallet og mad !!

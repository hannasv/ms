# %% [markdown]
# # Checking that all models are run

# %%
import os
import glob
import xarray as xr 
import numpy as np

# %%
#python_path = '/home/hanna/MS-thesis/python_figs/status_AR/'

for path in glob.glob('/home/hanna/EX3_Results_AR/*'): 
    for i in range(6):
        if i > 0:
            tr_files = glob.glob(path+'/*performance*TR*L{}*'.format(i))
            print(tr_files[0])
            print(len(tr_files))
                       
        ar_files = glob.glob(path+'/*performance*AR*L{}*'.format(i))
        print(ar_files[0])
        print(len(ar_files))
# Out:
# /home/hanna/EX3_Results_AR/AR-B-5/performance_AR-B-5-L0_-0.25_30.0.nc
# 10790
# /home/hanna/EX3_Results_AR/AR-B-5/performance_TR-B-5-L1_-0.25_30.0.nc
# 10790
# /home/hanna/EX3_Results_AR/AR-B-5/performance_AR-B-5-L1_-0.25_30.0.nc
# 10790
# /home/hanna/EX3_Results_AR/AR-B-5/performance_TR-B-5-L2_-0.25_30.0.nc
# 10790
# /home/hanna/EX3_Results_AR/AR-B-5/performance_AR-B-5-L2_-0.25_30.0.nc
# 10790
# /home/hanna/EX3_Results_AR/AR-B-5/performance_TR-B-5-L3_-0.25_30.0.nc
# 10789
# /home/hanna/EX3_Results_AR/AR-B-5/performance_AR-B-5-L3_-0.25_30.0.nc
# 10789
# /home/hanna/EX3_Results_AR/AR-B-5/performance_TR-B-5-L4_-0.25_30.0.nc
# 10789
# /home/hanna/EX3_Results_AR/AR-B-5/performance_AR-B-5-L4_-0.25_30.0.nc
# 10789
# /home/hanna/EX3_Results_AR/AR-B-5/performance_TR-B-5-L5_-0.25_30.0.nc
# 10789
# /home/hanna/EX3_Results_AR/AR-B-5/performance_AR-B-5-L5_-0.25_30.0.nc
# 10789
# /home/hanna/EX3_Results_AR/AR-T-5/performance_AR-T-5-L0_-0.25_30.0.nc
# 10601
# ...

# %% [markdown]
# # Hours in train, test and validation

# %%
import glob

# %%
lh_files = glob.glob('/home/hanna/lagrings/ar_data/*.nc')

# %%
lh_files[0]
# Out:
# '/home/hanna/lagrings/ar_data/all_vars_lat_lon_30.0_-15.0.nc'

# %%
import xarray as xr

# %%
data = xr.open_dataset('/home/hanna/lagrings/ar_data/all_vars_lat_lon_30.0_-15.0.nc')

# %%
data.sel(time = slice('2004-03-1', '2012-12-31'))
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 77472)
# Coordinates:
#     latitude       float64 30.0
#     longitude      float64 -15.0
#   * time           (time) datetime64[ns] 2004-03-01 ... 2012-12-31T23:00:00
#     number         int64 0
#     step           timedelta64[ns] 00:00:00
#     isobaricInhPa  int64 1000
#     valid_time     (time) datetime64[ns] ...
#     surface        int64 0
# Data variables:
#     q              (time) float32 ...
#     r              (time) float32 ...
#     t2m            (time) float32 ...
#     sp             (time) float32 ...
#     tcc            (time) float64 ...
#     nr_nans        (time) float64 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
data.sel(time = slice('2012', '2014-12-31'))
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 26304)
# Coordinates:
#     latitude       float64 30.0
#     longitude      float64 -15.0
#   * time           (time) datetime64[ns] 2012-01-01 ... 2014-12-31T23:00:00
#     number         int64 0
#     step           timedelta64[ns] 00:00:00
#     isobaricInhPa  int64 1000
#     valid_time     (time) datetime64[ns] ...
#     surface        int64 0
# Data variables:
#     q              (time) float32 ...
#     r              (time) float32 ...
#     t2m            (time) float32 ...
#     sp             (time) float32 ...
#     tcc            (time) float64 ...
#     nr_nans        (time) float64 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
data.sel(time = slice('2014', '2018-12-31'))
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 43824)
# Coordinates:
#     latitude       float64 30.0
#     longitude      float64 -15.0
#   * time           (time) datetime64[ns] 2014-01-01 ... 2018-12-31T23:00:00
#     number         int64 0
#     step           timedelta64[ns] 00:00:00
#     isobaricInhPa  int64 1000
#     valid_time     (time) datetime64[ns] ...
#     surface        int64 0
# Data variables:
#     q              (time) float32 ...
#     r              (time) float32 ...
#     t2m            (time) float32 ...
#     sp             (time) float32 ...
#     tcc            (time) float64 ...
#     nr_nans        (time) float64 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
data.sel(time = slice('2014', '2018-12-31'))
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 43824)
# Coordinates:
#     latitude       float64 30.0
#     longitude      float64 -15.0
#   * time           (time) datetime64[ns] 2014-01-01 ... 2018-12-31T23:00:00
#     number         int64 0
#     step           timedelta64[ns] 00:00:00
#     isobaricInhPa  int64 1000
#     valid_time     (time) datetime64[ns] ...
#     surface        int64 0
# Data variables:
#     q              (time) float32 ...
#     r              (time) float32 ...
#     t2m            (time) float32 ...
#     sp             (time) float32 ...
#     tcc            (time) float64 ...
#     nr_nans        (time) float64 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

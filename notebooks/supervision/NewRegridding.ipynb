# %%
path = '/home/hanna/MS/sclouds/io/'

# %%
import glob
import xarray as xr

# %%
glob.glob(path + '*.nc')
# Out:
# ['/home/hanna/MS/sclouds/io/2005_04_tcc.nc',
#  '/home/hanna/MS/sclouds/io/2005_03_tcc.nc']

# %%
xr.open_dataset('/home/hanna/MS/sclouds/io/2005_04_tcc.nc')['tcc'].mean()
# Out:
# <xarray.DataArray 'tcc' ()>
# array(0.53658144)

# %%
xr.open_dataset('/home/hanna/MS/sclouds/io/2005_03_tcc.nc')['tcc'].mean()
# Out:
# <xarray.DataArray 'tcc' ()>
# array(0.58434716)

# %%
data = xr.open_dataset('/home/hanna/lagrings/results/stats/monthly_mean/monthly_means_updated_3.nc')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.argwhere(np.isnan(data['tcc'].values))
# Out:
# array([[12]])

# %%
data['date_tcc'].values[12]
# Out:
# numpy.datetime64('2005-04-01T00:00:00.000000000')

# %% [markdown]
# # Get filters values to and make a hack in monthly mean plot.

# %%
from sclouds.io import Filter

# %%
from sclouds.io import Filter

var = 'tcc'

data   = xr.open_dataset('/home/hanna/MS/sclouds/io/2005_04_tcc.nc')
f_land = Filter('land').set_data(data = data, variable = var)
f_sea  = Filter('sea').set_data(data = data, variable = var)

mean_all  = np.nanmean(data[var].values)
mean_land = f_land.get_mean()
mean_sea  = f_sea.get_mean()

# %%
mean_all, mean_sea, mean_land
# Out:
# (0.5365814400731989, 0.5913059195264028, 0.4896591545998645)

# %%
ds = xr.open_dataset('/home/hanna/lagrings/results/stats/monthly_mean/monthly_means_updated_3.nc')

# %%
ds['tcc'][12] = mean_all
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-2a0a2f31150f> in <module>
# ----> 1 ds['tcc'][12] = mean_all
#
# ~/anaconda3/envs/final/lib/python3.7/site-packages/xarray/core/dataarray.py in __setitem__(self, key, value)
#     646                 for k, v in self._item_key_to_dict(key).items()
#     647             }
# --> 648             self.variable[key] = value
#     649
#     650     def __delitem__(self, key: Any) -> None:
#
# ~/anaconda3/envs/final/lib/python3.7/site-packages/xarray/core/variable.py in __setitem__(self, key, value)
#    2137
#    2138     def __setitem__(self, key, value):
# -> 2139         raise TypeError("%s values cannot be modified" % type(self).__name__)
#    2140
#    2141     @classmethod
#
# TypeError: IndexVariable values cannot be modified

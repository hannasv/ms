# %% [markdown]
# # Compute Total MAE

# %%
import glob
import xarray as xr

# %%
glob.glob('/home/hanna/TEMP_MODELS/*.nc')
# Out:
# ['/home/hanna/TEMP_MODELS/AR-B-5_weights_L1.nc',
#  '/home/hanna/TEMP_MODELS/{}_L1.nc']

# %%
data = xr.open_dataset('/home/hanna/TEMP_MODELS/{}_L1.nc')

# %%
data['mae_test'].plot()

# %%
data.mae_test.sum()*43680
# Out:
# <xarray.DataArray 'mae_test' ()>
# array(28503435.64186447)

# %%
import xarray as xr
import glob
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
data = xr.open_dataset('/home/hanna/lagrings/results/stats/monthly_mean/monthly_means_updated_3.nc')

# %%
plt.plot(data['date_tcc'].values, data['tcc'].values)

# %%
data['tcc'].values[12]
# Out:
# nan

# %%
data['date_tcc'].values[12]
# Out:
# numpy.datetime64('2005-04-01T00:00:00.000000000')

# %%
glob.glob('/home/hanna/lagrings/ERA5_monthly/*2005*04*tcc*')
# Out:
# ['/home/hanna/lagrings/ERA5_monthly/2005_04_tcc.nc']

# %%
xr.open_dataset('/home/hanna/lagrings/ERA5_monthly/2005_04_tcc.nc').mean(skipna=True)
# Out:
# /home/hanna/anaconda3/envs/final/lib/python3.7/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     tcc      float64 nan

# %%
data = xr.open_dataset('/home/hanna/lagrings/ERA5_monthly/2005_04_tcc.nc')

# %%
data['tcc'].values
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, ..., nan, nan, nan],
# ...

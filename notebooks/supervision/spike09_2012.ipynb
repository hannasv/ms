# %%
import numpy as np
import glob
import xarray as xr

import matplotlib.pyplot as plt

# %%
data.isel(time = 24)['tcc'].plot()

# %%
data.isel(time = 23)['tcc'].plot()

# %%
data.isel(time = 22)['tcc'].plot()

# %%
data.isel(time = 21)['tcc'].plot()

# %%
data.isel(time = 25)['tcc'].plot()

# %%
rel_indecies = [21, 22, 23, 24, 25]

# %%
# Out:
# Finished tcc

# %%
str(data.isel(time = i)['time'].values)[:-16]
# Out:
# '2012-09-02T01'
